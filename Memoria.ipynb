# %% [markdown]
# # EDA - Global Food Waste

# %% [markdown]
# En este trabajo, se realizó un análisis exploratorio de datos (EDA) para investigar el desperdicio global de
# alimentos. El cuadreno tiene como objetivo explorar y evaluar los datos globales sobre el desperdicio de alimentos basado en un estudio de la FAO desde 2000 a 2020. Se buscaràn puntos débiles en la cadena de suministro, y también verificar la coherencia/precisión de los datos a medida que avanzamos.
# Se plantearon cinco hipótesis y se analizaron los datos para determinar su validez. Las hipótesis son
# las siguientes:
#
# **HIPOTESIS:**<br>
#
# * Hipotesis 1: La FAO establece un desperdicio global de 32%, es este dato consistente con su
# base de datos?
#
# * Hipótesis 2: Los países industrializados tienen sistemas alimentarios más complejos y
# sofisticados que los países en desarrollo, esto hace que produzcan más desperdicio.
#
# * Hipótesis 3: La criba estética es esponsable por la mayor parte de las pérdidas de
# alimentos o al menos equiparable con las pérdidas durante la producción, cosecha o
# distribución.
#
# * Hipotesis 4: Los mayores productores mundiales de grano y cereal, incluyendo pan y arroz,
# son paìses en desarrollo como Brasil, Indonesia, Argentina e India, la falta de
# infraestructura adecuada para el almacenaje y el transporte deriva en que las mayores pérdidas de alimentos se den en granos y cereales
#
# * Hipótesis 5: El desperdicio global de alimentos es un problema que afecta a todos los países por igual
#
# ## Análisis
#
# * Porcentaje de perdida global
# * El desperdicio por paìs por año
# * Perdidas globales por año en las distintas etapas de la cadena de alimentos
# * Las causas màs comunes de las pėrdidas
# * Paìses con mayor y menor porcentaje de perdida alimentaria
# * Alimentos màs desperdiciados
# * Uso de agua dulce en la produccion de alimentos

# %% [markdown]
# ### Datos:
# El conjunto de datos de la FAO descargable desde aquí: https://www.fao.org/platform-food-loss-waste/flw-data/ contiene datos e información de bases de datos, informes y estudios de acceso público que miden la pérdida y el desperdicio de alimentos en productos alimentarios, etapas de la cadena de valor y áreas geográficas desde 2000 hasta 2022

# %% [markdown]
# ### Data sets:

# %%
import pandas as pd
df2 = pd.read_csv('/Users/miguelopez/Desktop/Food_waste_EDA/fao_global_food_waste_2000_2021.csv')
df3 = pd.read_csv('/Users/miguelopez/Desktop/Food_waste_EDA/water-withdrawals-per-kg-poore.csv')

# %%
df2.head()
# Out:
#    m49_code  country region cpc_code                      commodity  year  \
# 0       104  Myanmar    NaN     0142  Groundnuts, excluding shelled  2009
# 1       104  Myanmar    NaN     0142  Groundnuts, excluding shelled  2008
# 2       104  Myanmar    NaN     0142  Groundnuts, excluding shelled  2007
# 3       104  Myanmar    NaN     0142  Groundnuts, excluding shelled  2006
# 4       104  Myanmar    NaN     0142  Groundnuts, excluding shelled  2005
#
#    loss_percentage loss_percentage_original loss_quantity activity  \
# 0             5.22                    5.22%         68100      NaN
# 1             5.43                    5.43%         65240      NaN
# 2             5.61                    5.61%         61080      NaN
# 3             5.40                     5.4%         55270      NaN
# 4             5.00                       5%         51970      NaN
#
#     food_supply_stage treatment cause_of_loss sample_size  \
# ...

# %%
df3.head()
# Out:
#               Entity  Code  Year  \
# 0             Apples   NaN  2010
# 1            Bananas   NaN  2010
# 2             Barley   NaN  2010
# 3   Beef (beef herd)   NaN  2010
# 4  Beef (dairy herd)   NaN  2010
#
#    Freshwater withdrawals per kilogram (Poore & Nemecek, 2018)
# 0                                              180.1
# 1                                              114.5
# 2                                               17.1
# 3                                             1451.2
# 4                                             2714.3
